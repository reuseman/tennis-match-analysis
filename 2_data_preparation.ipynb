# %% [markdown]
# # Players dataset preparation

# %% [markdown]
# ## Reading and initial processing

# %%
import pandas as pd
import numpy as np

# Visualization
import plotly.express as px
import plotly.io as pio
pd.options.plotting.backend = 'plotly'
pio.templates.default = "seaborn"

# %%
# Read datasets
df_tennis = pd.read_csv("./datasets/tennis_matches_cleaned.csv", parse_dates=["tourney_date"])
df_male = pd.read_csv("./datasets/male_players.csv")
df_female = pd.read_csv("./datasets/female_players.csv")

df_male.drop_duplicates(inplace=True)
df_female.drop_duplicates(inplace=True)

def preprocess_strings(df):
    df = df.applymap(lambda x:x.lower().strip() if type(x) == str else x)
    return df.replace(r"\s{2,}", " ", regex=True)

df_tennis.tourney_date = pd.to_datetime(df_tennis.tourney_date, format='%Y%m%d')

# Normalize strings
df_tennis = preprocess_strings(df_tennis)
df_male = preprocess_strings(df_male)
df_female = preprocess_strings(df_female)

# %%
# Create a new players dataset whose name is the concatenation of the name and the surname for the male and female players
df = pd.concat([df_male.name + " " + df_male.surname], axis=1, keys=["name", "gender"])
df["gender"] = "m"
df_players = df

df = pd.concat([df_female.name + " " + df_female.surname], axis=1, keys=["name", "gender"])
df["gender"] = "f"
df_players = df_players.append(df)

# Remove duplicates arising from the intersection
df_players = df_players.drop_duplicates(subset=["name"])
df_players = df_players.sort_values(by=["name"])
df_players.reset_index(drop=True, inplace=True)

# Merge the players dataset with the tennis dataset
df = pd.merge(df_tennis, df_players.rename(columns = {'name': 'winner_name', 'gender':'winner_gender'}), on="winner_name", how="left")
df = pd.merge(df, df_players.rename(columns = {'name': 'loser_name', 'gender':'loser_gender'}), on="loser_name", how="left")

# Find the players who do not have a gender and assign them the most common among the genders of the players they played with. 
winners = df[df.winner_gender.isnull()].groupby(["winner_name", "loser_gender"]).loser_gender.count().reset_index(name="occurrences").rename(columns={"winner_name":"name", "loser_gender":"gender"})

losers = df[df.loser_gender.isnull()].groupby(["loser_name", "winner_gender"]).winner_gender.count().reset_index(name="occurrences").rename(columns={"loser_name":"name", "winner_gender":"gender"})

estimate = pd.concat([winners, losers]).groupby(["name", "gender"]).occurrences.sum().reset_index(name="occurrences")
estimate = estimate.sort_values(by=["name", "occurrences"], ascending=[1, 0]).drop_duplicates("name", keep="first").drop(columns=["occurrences"])

# Create the players dataset
df_players = df.loc[:, ['winner_name', 'winner_gender']].set_axis(['name', 'gender'], axis=1, inplace=False)
df_players = df_players.append(df.loc[:, ['loser_name', 'loser_gender']].set_axis(['name', 'gender'], axis=1, inplace=False))
df_players = df_players.append(estimate)
df_players = df_players.dropna().drop_duplicates()
df_players = df_players.sort_values(by=["name"]).reset_index(drop=True)
df_players.head()
# Out:
#               name gender
# 0        aada inna      f
# 1   aalisha alexis      f
# 2   aaliya ebrahim      f
# 3  aaliyah hohmann      f
# 4   aalyka ebrahim      f

# %%
df_tennis.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-m020     brisbane    hard       32.0             a
# 1           1  2019-m020     brisbane    hard       32.0             a
# 2           2  2019-m020     brisbane    hard       32.0             a
# 3           3  2019-m020     brisbane    hard       32.0             a
# 4           4  2019-m020     brisbane    hard       32.0             a
#
#   tourney_date  match_num  winner_id winner_entry  ... winner_rank  \
# 0   2018-12-31      300.0   105453.0          NaN  ...         9.0
# 1   2018-12-31      299.0   106421.0          NaN  ...        16.0
# 2   2018-12-31      298.0   105453.0          NaN  ...         9.0
# 3   2018-12-31      297.0   104542.0           pr  ...       239.0
# 4   2018-12-31      296.0   106421.0          NaN  ...        16.0
#
#   winner_rank_points  loser_rank loser_rank_points  tourney_spectators  \
# 0             3590.0        16.0            1977.0              3928.0
# 1             1977.0       239.0             200.0              3928.0
# 2             3590.0        40.0            1050.0              3928.0
# 3              200.0        31.0            1298.0              3928.0
# 4             1977.0        18.0            1855.0              3928.0
#
#    tourney_revenue   score_norm                      games_list w_gmsWon  \
# 0        742618.69  6-4 3-6 6-2  ['6', '4', '3', '6', '6', '2']       15
# 1        742618.69      7-6 6-2            ['7', '6', '6', '2']       13
# 2        742618.69      6-2 6-2            ['6', '2', '6', '2']       12
# 3        742618.69      6-4 7-6            ['6', '4', '7', '6']       13
# 4        742618.69  6-7 6-3 6-4  ['6', '7', '6', '3', '6', '4']       18
#
#    l_gmsWon
# 0        12
# 1         8
# 2         4
# 3        10
# 4        14
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Minutes

# %% [markdown]
# ### Tourneys played

# %%
df_w = df_tennis.loc[:, ['winner_name', 'tourney_id']].rename(columns={'winner_name': 'name'})
df_l = df_tennis.loc[:, ['loser_name', 'tourney_id']].rename(columns={'loser_name': 'name'})

#  giocatori e relativo numero di partecipazioni ai tornei
df = pd.concat([df_w, df_l]).groupby('name').tourney_id.nunique().reset_index(name="total_tourneys_played")

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare dataframe
df
# Out:
#                       name  total_tourneys_played
# 0                aada inna                      1
# 1           aalisha alexis                      2
# 2           aaliya ebrahim                      7
# 3          aaliyah hohmann                      2
# 4           aalyka ebrahim                      4
# ...                    ...                    ...
# 10098      zuzana zalabska                      1
# 10099      zuzana zlochova                     88
# 10100      zuzanna bednarz                      2
# 10101  zuzanna szczepanska                      3
# 10102   zvonimir oreskovic                      1
#
# [10103 rows x 2 columns]

# %% [markdown]
# ### Matches played

# %%
df_w = df_tennis.loc[:, ['winner_name', 'tourney_id']].rename(columns={'winner_name': 'name'})
df_l = df_tennis.loc[:, ['loser_name', 'tourney_id']].rename(columns={'loser_name': 'name'})

#  giocatori e relativo numero di match giocati
df = pd.concat([df_w, df_l]).groupby('name').tourney_id.count().reset_index(name="total_matches_played")

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare dataframe
df
# Out:
#                       name  total_matches_played
# 0                aada inna                     1
# 1           aalisha alexis                     2
# 2           aaliya ebrahim                     9
# 3          aaliyah hohmann                     3
# 4           aalyka ebrahim                     4
# ...                    ...                   ...
# 10098      zuzana zalabska                     3
# 10099      zuzana zlochova                   179
# 10100      zuzanna bednarz                     2
# 10101  zuzanna szczepanska                     3
# 10102   zvonimir oreskovic                     1
#
# [10103 rows x 2 columns]

# %% [markdown]
# ### Matches won

# %%
df = df_tennis.loc[:, ['winner_name', 'tourney_id']].rename(columns={'winner_name': 'name'})

#  giocatori e relativo numero di match vinti
df = df.groupby('name').tourney_id.count().reset_index(name="total_matches_won")

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare dataframe
df
# Out:
#                    name  total_matches_won
# 0        aaliya ebrahim                  2
# 1       aaliyah hohmann                  1
# 2         aanu ayegbusi                  3
# 3         aaron addison                  2
# 4        aastha dargude                  1
# ...                 ...                ...
# 6174    zulay castaneda                  1
# 6175   zuzana luknarova                  1
# 6176  zuzana pavelekova                  2
# 6177    zuzana zalabska                  2
# 6178    zuzana zlochova                 93
#
# [6179 rows x 2 columns]

# %% [markdown]
# ### Mean, max, min won_matches_ratio in a tourney

# %%
df_w = df_tennis.loc[:, ['winner_name', 'tourney_id']].rename(columns={'winner_name': 'name'})
df_l = df_tennis.loc[:, ['loser_name', 'tourney_id']].rename(columns={'loser_name': 'name'})

matches_won_per_tourney = df_w.groupby(['name', 'tourney_id']).tourney_id.count().reset_index(name="total_matches_won_per_tourney")

matches_played_per_tourney = pd.concat([df_w, df_l]).groupby(['name', 'tourney_id']).tourney_id.count().reset_index(name="total_matches_played_per_tourney")
df = matches_played_per_tourney.merge(matches_won_per_tourney, on=['name', 'tourney_id'], how="left")
df.total_matches_won_per_tourney = df.total_matches_won_per_tourney.fillna(0).astype('Int32')
df["won_ratio"] = df.total_matches_won_per_tourney / df.total_matches_played_per_tourney

df = df.groupby(['name']).won_ratio.agg(mean_won_ratio="mean", max_won_ratio="max", min_won_ratio="min")
df_players = df_players.merge(df, on="name")
del matches_won_per_tourney, matches_played_per_tourney

# %% [markdown]
# ### Height

# %% [markdown]
# Feature probabilmente inutilizzabile, l'abbiamo solo per 541 giocatori

# %%
df_w = df_tennis.loc[:, ['winner_name', 'winner_ht', 'tourney_date']].rename(columns={'winner_name': 'name', 'winner_ht': 'ht'})
df_l = df_tennis.loc[:, ['loser_name', 'loser_ht', 'tourney_date']].rename(columns={'loser_name': 'name', 'loser_ht': 'ht'})

# giocatori e relativa altezza
df = pd.concat([df_w, df_l]).sort_values('tourney_date', ascending='False').groupby('name').ht.first().reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('Numero giocatori per cui abbiamo altezza ' + str(len(df[df.ht.notnull()])))
print('Numero giocatori totali ' + str(len(df)))
df
# Out:
# Numero giocatori per cui abbiamo altezza 541
# Numero giocatori totali 10103
#                       name  ht
# 0                aada inna NaN
# 1           aalisha alexis NaN
# 2           aaliya ebrahim NaN
# 3          aaliyah hohmann NaN
# 4           aalyka ebrahim NaN
# ...                    ...  ..
# 10098      zuzana zalabska NaN
# 10099      zuzana zlochova NaN
# 10100      zuzanna bednarz NaN
# 10101  zuzanna szczepanska NaN
# 10102   zvonimir oreskovic NaN
#
# [10103 rows x 2 columns]

# %% [markdown]
# ### Age

# %%
df_w = df_tennis.loc[:, ['winner_name', 'winner_age', 'tourney_date']].rename(columns={'winner_name': 'name', 'winner_age': 'age'})
df_l = (df_tennis.loc[:, ['loser_name', 'loser_age', 'tourney_date']]).rename(columns={'loser_name': 'name', 'loser_age': 'age'})

# giocatori e relativa età
df = pd.concat([df_w, df_l]).sort_values('tourney_date', ascending='False').groupby('name').age.first().reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('Numero giocatori per cui abbiamo l\'età ' + str(len(df[df.age.notnull()])))
print('Numero giocatori totali ' + str(len(df)))
df
# Out:
# Numero giocatori per cui abbiamo l'età 8012
# Numero giocatori totali 10103
#                       name        age
# 0                aada inna        NaN
# 1           aalisha alexis        NaN
# 2           aaliya ebrahim        NaN
# 3          aaliyah hohmann        NaN
# 4           aalyka ebrahim        NaN
# ...                    ...        ...
# 10098      zuzana zalabska  30.647502
# 10099      zuzana zlochova  26.020534
# 10100      zuzanna bednarz        NaN
# 10101  zuzanna szczepanska        NaN
# 10102   zvonimir oreskovic  21.587953
#
# [10103 rows x 2 columns]

# %% [markdown]
# ### Hand

# %%
df_w = df_tennis.loc[:, ['winner_name', 'winner_hand']].rename(columns={'winner_name': 'name', 'winner_hand': 'hand'})
df_l = (df_tennis.loc[:, ['loser_name', 'loser_hand']]).rename(columns={'loser_name': 'name', 'loser_hand': 'hand'})

# giocatori e relativa mano preferita
df = pd.concat([df_w, df_l]).groupby('name').hand.agg(pd.Series.mode).reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('Numero giocatori per cui abbiamo la mano ' + str(len(df[df.hand.notnull()])))
print('Numero giocatori totali ' + str(len(df)))
df
# Out:
# Numero giocatori per cui abbiamo la mano 10103
# Numero giocatori totali 10103
#                       name hand
# 0                aada inna    u
# 1           aalisha alexis    u
# 2           aaliya ebrahim    r
# 3          aaliyah hohmann    u
# 4           aalyka ebrahim    u
# ...                    ...  ...
# 10098      zuzana zalabska    r
# 10099      zuzana zlochova    r
# 10100      zuzanna bednarz    u
# 10101  zuzanna szczepanska    r
# 10102   zvonimir oreskovic    r
#
# [10103 rows x 2 columns]

# %% [markdown]
# ### Ranking

# %%
df_w = df_tennis.loc[:, ['winner_name', 'winner_rank_points', 'tourney_date']].rename(columns={'winner_name': 'name', 'winner_rank_points': 'rank_points'})
df_l = (df_tennis.loc[:, ['loser_name', 'loser_rank_points', 'tourney_date']]).rename(columns={'loser_name': 'name', 'loser_rank_points': 'rank_points'})

# giocatori e relative misure su ranking (varianza, media, max)
df = pd.concat([df_l, df_w]).sort_values('tourney_date', ascending = False).groupby('name').rank_points.agg(mean_rank_points='mean', max_rank_points='max', last_rank_points='first', variance_rank_points=lambda x: np.var(x,ddof=0)).reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('numero di valori null mean_rank_points ' + str(df.mean_rank_points.isna().sum()) + ' su ' + str(len(df.mean_rank_points)))
print('numero di valori null max_rank_points ' + str(df.max_rank_points.isna().sum()) + ' su ' + str(len(df.mean_rank_points)))
print('numero di valori null last_rank_points ' + str(df.last_rank_points.isna().sum()) + ' su ' + str(len(df.mean_rank_points)))
print('numero di valori null variance_rank_points ' + str(df.variance_rank_points.isna().sum()) + ' su ' + str(len(df.variance_rank_points)))
df
# Out:
# numero di valori null mean_rank_points 5656 su 10103
# numero di valori null max_rank_points 5656 su 10103
# numero di valori null last_rank_points 5656 su 10103
# numero di valori null variance_rank_points 5656 su 10103
#                       name  mean_rank_points  max_rank_points  \
# 0                aada inna               NaN              NaN
# 1           aalisha alexis               NaN              NaN
# 2           aaliya ebrahim               NaN              NaN
# 3          aaliyah hohmann               NaN              NaN
# 4           aalyka ebrahim               NaN              NaN
# ...                    ...               ...              ...
# 10098      zuzana zalabska         14.000000             14.0
# 10099      zuzana zlochova         87.782123            166.0
# 10100      zuzanna bednarz               NaN              NaN
# 10101  zuzanna szczepanska               NaN              NaN
# 10102   zvonimir oreskovic               NaN              NaN
#
#        last_rank_points  variance_rank_points
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
# ...                 ...                   ...
# 10098              14.0              0.000000
# 10099             142.0           1924.036328
# 10100               NaN                   NaN
# 10101               NaN                   NaN
# 10102               NaN                   NaN
#
# [10103 rows x 5 columns]

# %% [markdown]
# ### Spectator

# %%
df_w = df_tennis.loc[:, ['winner_name', 'tourney_spectators']].rename(columns = {'winner_name': 'name'})
df_l = (df_tennis.loc[:, ['loser_name', 'tourney_spectators']]).rename(columns = {'loser_name': 'name'})

# giocatori e relative misure sugli spectator (media e max)
df = pd.concat([df_l, df_w]).groupby('name').tourney_spectators.agg(mean_tourney_spectators='mean', max_tourney_spectators='max').reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('Numero di nulli in mean_tourney_spectators ' + str(df.mean_tourney_spectators.isna().sum()))
print('Numero di nulli in max_tourney_spectators ' + str(df.max_tourney_spectators.isna().sum()))
df
# Out:
# Numero di nulli in mean_tourney_spectators 0
# Numero di nulli in max_tourney_spectators 0
#                       name  mean_tourney_spectators  max_tourney_spectators
# 0                aada inna              4059.000000                  4059.0
# 1           aalisha alexis              3237.500000                  3628.0
# 2           aaliya ebrahim              3632.666667                  4070.0
# 3          aaliyah hohmann              2792.666667                  2996.0
# 4           aalyka ebrahim              3207.750000                  3943.0
# ...                    ...                      ...                     ...
# 10098      zuzana zalabska              1303.000000                  1303.0
# 10099      zuzana zlochova              3236.458101                 10338.0
# 10100      zuzanna bednarz              2206.500000                  2372.0
# 10101  zuzanna szczepanska              2785.333333                  3628.0
# 10102   zvonimir oreskovic              6768.000000                  6768.0
#
# [10103 rows x 3 columns]

# %% [markdown]
# ### Revenue

# %%
df_w = df_tennis.loc[:, ['winner_name', 'tourney_revenue']].rename(columns = {'winner_name': 'name'})
df_l = (df_tennis.loc[:, ['loser_name', 'tourney_revenue']]).rename(columns = {'loser_name': 'name'})

# giocatori e relative misure su revenue (media e max)
df = pd.concat([df_l, df_w]).groupby('name').tourney_revenue.agg(mean_tourney_revenue='mean', max_tourney_revenue='max').reset_index()

# aggiungere feature al data_frame dei profili dei player
df_players = df_players.merge(df, on="name")

# stampare numero di valori nulli e dataframe
print('Numero di nulli in mean_tourney_revenue ' + str(df.mean_tourney_revenue.isna().sum()))
print('Numero di nulli in max_tourney_revenue ' + str(df.max_tourney_revenue.isna().sum()))
df
# Out:
# Numero di nulli in mean_tourney_revenue 0
# Numero di nulli in max_tourney_revenue 0
#                       name  mean_tourney_revenue  max_tourney_revenue
# 0                aada inna         939835.240000            939835.24
# 1           aalisha alexis         704802.720000            717933.37
# 2           aaliya ebrahim         737944.000000            885863.35
# 3          aaliyah hohmann         551917.330000            593484.95
# 4           aalyka ebrahim         713766.042500            885863.35
# ...                    ...                   ...                  ...
# 10098      zuzana zalabska         239390.330000            239390.33
# 10099      zuzana zlochova         650492.769274           2291040.00
# 10100      zuzanna bednarz         419291.125000            454394.49
# 10101  zuzanna szczepanska         569497.023333            639257.36
# 10102   zvonimir oreskovic         715704.560000            715704.56
#
# [10103 rows x 3 columns]

# %% [markdown]
# ## Feature analysis

# %%
df_players.describe()
# Out:
#        total_tourneys_played  total_matches_played  total_matches_won  \
# count            6179.000000           6179.000000        6179.000000
# mean               29.434213             58.852403          30.062955
# std                37.293222             81.333878          46.458837
# min                 1.000000              1.000000           1.000000
# 25%                 4.000000              6.000000           2.000000
# 50%                12.000000             19.000000           7.000000
# 75%                40.000000             75.500000          36.000000
# max               175.000000            387.000000         289.000000
#
#        mean_won_ratio  max_won_ratio  min_won_ratio          ht          age  \
# count     6179.000000    6179.000000    6179.000000  505.000000  5250.000000
# mean         0.306561       0.726224       0.052722  181.283168    20.887511
# std          0.149703       0.196863       0.169440    8.934340     4.699697
# min          0.013889       0.333333       0.000000  155.000000    14.006845
# 25%          0.200000       0.500000       0.000000  175.000000    17.300479
# 50%          0.294093       0.666667       0.000000  183.000000    19.753593
# 75%          0.392857       1.000000       0.000000  188.000000    23.624914
# max          1.000000       1.000000       1.000000  211.000000    53.642710
#
#        mean_rank_points  max_rank_points  last_rank_points  \
# count       3826.000000      3826.000000       3826.000000
# mean         163.657548       314.335860        194.495034
# std          474.616229       911.911784        627.980235
# min            1.000000         1.000000          1.000000
# 25%            9.000000        13.000000          8.000000
# 50%           31.128398        52.000000         30.000000
# 75%          122.307604       219.000000        116.000000
# max        10235.315634     16950.000000      12113.000000
#
#        variance_rank_points  mean_tourney_spectators  max_tourney_spectators  \
# count          3.826000e+03              6179.000000             6179.000000
# mean           5.972712e+04              3473.790618             6413.273669
# std            5.894063e+05              1009.885439             4652.622346
# min            0.000000e+00               118.666667              158.000000
# 25%            4.892231e+00              3059.886508             3834.000000
# 50%            1.477467e+02              3255.500000             4422.000000
# 75%            2.461451e+03              3623.365033             6305.000000
# max            2.061166e+07             15660.000000            18086.000000
#
#        mean_tourney_revenue  max_tourney_revenue
# count          6.179000e+03         6.179000e+03
# mean           6.950966e+05         1.487564e+06
# std            2.121458e+05         1.313040e+06
# min            2.355808e+04         3.076084e+04
# 25%            6.057221e+05         7.938150e+05
# 50%            6.529350e+05         9.628369e+05
# 75%            7.324217e+05         1.378907e+06
# max            5.002794e+06         5.002794e+06

# %% [markdown]
# ### Tourneys played

# %%
df_players.total_tourneys_played.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="4673d538-77d1-4320-92fe-4c5cdfe42eea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4673d538-77d1-4320-92fe-4c5cdfe42eea")) {                    Plotly.newPlot(                        "4673d538-77d1-4320-92fe-4c5cdfe42eea",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_tourneys_played<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_tourneys_played","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_tourneys_played","offsetgroup":"total_tourneys_played","orientation":"v","showlegend":true,"type":"histogram","x":[7,2,3,9,2,5,81,8,2,5,4,3,61,11,3,17,4,95,5,8,1,5,6,16,13,36,22,3,25,14,60,15,15,2,18,4,13,159,144,1,36,2,3,29,7,4,24,8,26,5,16,51,7,9,18,7,5,27,2,9,80,7,53,8,3,79,50,3,7,8,4,10,9,9,10,63,17,68,2,17,7,2,2,1,3,4,4,106,8,24,3,73,10,20,23,103,67,118,3,9,1,54,18,1,15,8,114,1,8,37,39,3,27,163,27,5,6,5,57,2,72,106,13,2,9,2,80,41,33,112,17,3,63,22,87,107,18,7,3,13,2,113,11,24,4,40,65,9,19,4,37,12,20,97,31,7,2,32,11,1,21,9,13,3,5,22,91,1,146,2,3,13,9,1,9,9,1,3,8,21,8,10,2,98,114,10,15,3,65,32,41,25,48,15,56,21,14,14,15,10,9,146,17,7,9,4,17,46,7,1,4,3,44,100,3,10,37,3,46,122,48,17,8,13,2,1,69,115,9,26,4,63,18,1,3,27,11,13,8,6,22,11,44,48,74,4,10,2,77,13,7,12,16,10,37,29,16,44,17,5,4,3,92,7,23,5,104,9,148,11,4,4,17,4,5,30,11,6,11,22,131,2,2,54,13,26,27,14,57,57,6,98,61,13,42,5,16,2,83,36,7,2,45,3,9,9,2,23,32,7,8,48,6,6,10,81,3,1,12,25,75,7,39,1,8,15,20,13,21,7,88,1,119,124,128,85,1,116,2,3,41,6,80,3,16,87,12,60,4,16,24,59,6,65,1,21,9,11,27,9,63,5,79,4,34,46,140,23,9,14,19,30,26,12,7,6,20,4,2,5,35,5,1,102,4,7,9,10,37,31,5,14,2,63,5,8,4,3,3,3,85,58,47,34,110,4,4,51,4,26,16,3,82,65,4,10,12,13,2,3,1,8,2,2,2,5,10,9,17,149,48,57,1,1,10,17,3,3,5,5,14,2,9,17,23,94,1,154,45,90,94,17,19,2,14,69,13,10,25,121,12,37,41,79,100,23,16,23,13,2,71,36,40,2,2,76,21,1,5,51,80,52,10,1,10,6,132,3,9,19,1,12,7,101,12,2,11,1,6,54,3,10,8,73,3,4,60,1,2,12,7,4,8,7,10,14,21,43,7,16,7,10,6,6,10,22,1,51,10,17,9,17,170,34,2,126,3,150,9,19,64,9,69,5,1,111,116,10,7,54,6,63,12,36,7,143,3,7,80,4,71,72,32,2,24,13,18,6,154,19,1,30,7,17,4,58,2,7,3,53,47,69,146,21,19,42,57,24,9,39,69,123,54,25,36,5,5,71,4,5,3,2,45,3,112,59,16,2,69,49,27,6,17,70,105,40,2,16,99,14,70,33,19,147,38,13,3,9,3,31,1,54,1,3,10,16,39,26,148,69,16,18,128,3,113,38,6,3,10,10,7,75,11,51,53,6,33,1,108,131,4,48,3,67,21,7,73,5,1,4,82,6,6,28,9,120,2,3,34,4,3,4,37,12,76,1,3,3,84,19,3,6,2,34,45,2,97,11,64,14,1,106,7,1,1,5,2,8,32,28,5,7,2,8,45,2,50,6,17,16,11,19,7,89,1,20,22,49,101,6,2,4,5,2,93,18,31,38,13,5,20,1,4,49,3,8,18,6,31,27,149,27,4,5,1,1,26,6,14,17,3,1,7,6,4,18,62,2,5,48,66,3,6,146,46,12,8,35,79,12,5,23,28,9,1,12,15,113,3,1,58,1,7,5,126,1,79,3,2,67,23,6,13,22,64,113,2,107,21,3,79,16,41,1,3,26,2,8,73,37,92,14,2,1,1,8,22,48,4,1,65,3,3,10,11,5,34,9,54,2,10,42,3,116,6,1,116,3,91,17,41,1,8,3,68,27,12,1,3,8,3,25,15,31,4,13,1,13,56,16,117,138,29,2,5,3,5,99,68,100,9,12,14,56,3,108,2,15,110,23,23,7,62,2,2,9,39,18,11,8,32,111,2,6,7,9,2,11,2,106,39,17,3,24,1,23,12,5,41,101,4,49,42,19,2,21,169,7,84,1,118,106,118,12,3,2,59,4,24,4,15,15,37,73,3,1,5,20,3,2,74,31,107,6,2,129,1,32,35,5,16,97,141,2,1,13,4,1,15,41,12,138,22,8,1,114,64,56,8,4,8,2,93,56,17,46,6,13,123,11,31,5,25,4,11,8,5,2,1,53,41,3,5,2,4,5,22,89,6,32,60,1,143,33,4,33,32,15,1,3,12,80,27,2,9,119,9,6,57,104,3,2,27,5,3,5,4,9,4,2,4,108,84,6,1,22,5,4,2,41,38,8,77,2,13,7,48,98,27,34,95,32,1,11,14,63,2,9,7,3,99,36,15,3,3,5,6,9,21,2,5,3,40,3,1,4,93,24,70,4,6,8,15,7,8,2,5,140,1,1,110,6,21,137,26,82,76,4,11,79,31,3,132,1,2,80,1,54,66,61,47,1,5,58,6,1,7,3,1,79,17,12,42,21,3,2,122,84,5,2,25,6,8,5,30,98,50,60,14,1,5,44,108,5,23,7,1,3,29,64,2,22,4,5,25,5,65,1,2,21,11,38,3,44,3,15,2,11 ...

# %%
np.log2(df_players.total_tourneys_played).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="5b155ad9-fb55-472a-bc0b-44658a3a2e0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b155ad9-fb55-472a-bc0b-44658a3a2e0c")) {                    Plotly.newPlot(                        "5b155ad9-fb55-472a-bc0b-44658a3a2e0c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_tourneys_played<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_tourneys_played","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_tourneys_played","offsetgroup":"total_tourneys_played","orientation":"v","showlegend":true,"type":"histogram","x":[2.807354922057604,1.0,1.584962500721156,3.169925001442312,1.0,2.321928094887362,6.339850002884624,3.0,1.0,2.321928094887362,2.0,1.584962500721156,5.930737337562887,3.4594316186372973,1.584962500721156,4.087462841250339,2.0,6.569855608330948,2.321928094887362,3.0,0.0,2.321928094887362,2.584962500721156,4.0,3.700439718141092,5.169925001442312,4.459431618637297,1.584962500721156,4.643856189774724,3.807354922057604,5.906890595608519,3.9068905956085187,3.9068905956085187,1.0,4.169925001442312,2.0,3.700439718141092,7.312882955284356,7.169925001442312,0.0,5.169925001442312,1.0,1.584962500721156,4.857980995127572,2.807354922057604,2.0,4.584962500721156,3.0,4.700439718141092,2.321928094887362,4.0,5.672425341971495,2.807354922057604,3.169925001442312,4.169925001442312,2.807354922057604,2.321928094887362,4.754887502163468,1.0,3.169925001442312,6.321928094887363,2.807354922057604,5.727920454563199,3.0,1.584962500721156,6.303780748177103,5.643856189774724,1.584962500721156,2.807354922057604,3.0,2.0,3.321928094887362,3.169925001442312,3.169925001442312,3.321928094887362,5.977279923499917,4.087462841250339,6.087462841250339,1.0,4.087462841250339,2.807354922057604,1.0,1.0,0.0,1.584962500721156,2.0,2.0,6.727920454563199,3.0,4.584962500721156,1.584962500721156,6.189824558880018,3.321928094887362,4.321928094887363,4.523561956057013,6.6865005271832185,6.066089190457772,6.882643049361842,1.584962500721156,3.169925001442312,0.0,5.754887502163468,4.169925001442312,0.0,3.9068905956085187,3.0,6.832890014164741,0.0,3.0,5.20945336562895,5.285402218862249,1.584962500721156,4.754887502163468,7.348728154231077,4.754887502163468,2.321928094887362,2.584962500721156,2.321928094887362,5.832890014164741,1.0,6.169925001442312,6.727920454563199,3.700439718141092,1.0,3.169925001442312,1.0,6.321928094887363,5.357552004618084,5.044394119358453,6.807354922057604,4.087462841250339,1.584962500721156,5.977279923499917,4.459431618637297,6.442943495848728,6.7414669864011465,4.169925001442312,2.807354922057604,1.584962500721156,3.700439718141092,1.0,6.820178962415188,3.4594316186372973,4.584962500721156,2.0,5.321928094887363,6.022367813028454,3.169925001442312,4.247927513443585,2.0,5.20945336562895,3.584962500721156,4.321928094887363,6.599912842187128,4.954196310386875,2.807354922057604,1.0,5.0,3.4594316186372973,0.0,4.392317422778761,3.169925001442312,3.700439718141092,1.584962500721156,2.321928094887362,4.459431618637297,6.507794640198696,0.0,7.189824558880018,1.0,1.584962500721156,3.700439718141092,3.169925001442312,0.0,3.169925001442312,3.169925001442312,0.0,1.584962500721156,3.0,4.392317422778761,3.0,3.321928094887362,1.0,6.614709844115208,6.832890014164741,3.321928094887362,3.9068905956085187,1.584962500721156,6.022367813028454,5.0,5.357552004618084,4.643856189774724,5.584962500721156,3.9068905956085187,5.807354922057604,4.392317422778761,3.807354922057604,3.807354922057604,3.9068905956085187,3.321928094887362,3.169925001442312,7.189824558880018,4.087462841250339,2.807354922057604,3.169925001442312,2.0,4.087462841250339,5.523561956057013,2.807354922057604,0.0,2.0,1.5849625007211 ...

# %% [markdown]
# ### Matches played

# %%
df_players.total_matches_played.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="1c7a8328-6751-43c7-bc3f-66d1e547ab3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c7a8328-6751-43c7-bc3f-66d1e547ab3c")) {                    Plotly.newPlot(                        "1c7a8328-6751-43c7-bc3f-66d1e547ab3c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_matches_played<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_matches_played","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_matches_played","offsetgroup":"total_matches_played","orientation":"v","showlegend":true,"type":"histogram","x":[9,3,6,11,3,6,157,16,3,12,5,6,126,14,4,23,4,201,8,11,2,8,12,29,26,51,34,6,36,21,118,18,18,3,30,5,19,326,289,2,69,3,3,69,23,5,44,9,50,8,23,90,8,17,26,9,6,40,9,12,168,10,144,11,4,159,90,4,10,10,5,12,13,11,17,115,21,118,3,20,8,4,3,1,4,7,5,231,11,36,4,129,18,30,27,201,112,232,5,29,2,86,26,2,21,11,231,2,11,78,77,6,53,326,49,8,9,11,94,3,154,182,16,3,12,3,208,72,64,204,19,6,139,39,183,220,22,8,4,22,3,248,21,28,6,71,140,10,38,8,70,21,32,197,51,8,3,57,12,2,23,17,24,4,6,37,150,2,309,3,4,20,19,2,12,12,4,4,15,27,10,14,4,229,272,29,18,6,155,65,80,53,81,34,90,33,19,23,32,17,16,328,30,11,14,4,34,83,10,2,5,4,90,193,11,22,71,5,76,378,101,24,9,17,6,2,122,249,12,56,6,141,33,2,5,41,31,18,12,11,39,23,91,89,183,5,15,5,96,18,11,15,24,18,62,49,28,67,27,7,5,4,191,12,42,9,228,10,280,17,5,5,29,6,7,60,15,13,19,40,280,4,4,82,24,49,66,26,98,106,7,232,138,20,99,6,24,4,148,59,12,4,74,4,10,10,5,36,77,12,13,71,15,8,17,156,4,2,16,38,171,10,55,2,22,25,24,15,33,14,140,3,252,254,270,159,2,262,3,4,80,8,175,5,29,150,16,117,5,28,27,130,10,127,2,46,13,25,30,11,160,8,208,7,62,84,279,44,14,26,46,45,47,14,16,7,21,7,3,9,50,13,3,247,5,12,17,11,62,51,6,20,3,117,5,10,6,6,6,4,159,109,114,53,256,4,5,69,7,36,31,4,186,123,5,15,16,19,3,4,2,9,3,3,3,6,14,23,24,296,119,100,2,2,17,28,4,4,6,6,19,3,13,27,39,212,2,296,102,223,234,20,32,3,31,186,18,17,33,260,17,71,81,181,237,32,24,43,18,3,126,70,117,3,4,163,32,2,10,147,199,116,12,2,11,8,298,4,19,47,2,16,19,220,40,4,18,4,9,96,7,14,11,189,8,4,118,2,4,14,9,6,12,9,11,20,42,79,10,18,8,16,10,8,21,27,6,87,14,45,20,33,313,67,3,250,7,297,12,43,126,16,182,6,5,198,239,17,8,102,8,131,31,64,13,281,4,12,239,6,125,165,55,3,43,15,30,9,328,33,3,58,9,22,5,120,3,8,4,104,74,143,380,40,24,52,183,54,16,78,137,287,84,46,73,7,6,156,6,14,4,3,75,4,260,138,35,4,123,59,35,8,31,149,298,62,4,24,248,33,137,95,53,243,70,29,3,11,5,61,2,94,2,8,20,20,97,34,298,176,27,27,307,4,274,44,12,4,26,20,7,138,17,108,120,10,41,1,271,262,5,87,4,166,30,9,157,6,2,5,114,10,8,40,18,263,3,4,61,5,12,8,55,23,142,2,6,8,191,30,5,7,4,61,126,4,188,28,136,16,2,234,13,4,1,7,3,13,85,53,7,11,3,15,65,3,85,12,22,27,17,26,12,157,1,33,31,107,219,7,3,8,16,3,200,58,45,76,20,8,31,2,5,95,6,12,24,8,58,49,387,30,7,10,2,1,46,9,19,30,4,2,7,7,5,38,157,3,7,65,157,4,10,307,68,17,17,58,158,22,6,49,52,10,2,18,27,230,5,2,140,2,8,7,337,2,276,6,2,143,57,7,18,47,90,236,3,238,29,3,191,35,81,2,5,35,3,9,154,77,204,22,3,1,3,9,44,116,5,2,120,4,7,20,13,7,56,12,101,3,31,64,4,185,13,1,243,5,218,23,65,2,14,7,168,42,21,3,4,12,5,45,19,59,9,23,2,14,109,32,292,308,61,3,8,8,10,256,124,169,12,30,22,134,4,238,3,20,230,44,27,9,87,4,3,10,64,28,21,18,62,280,3,7,8,10,3,14,5,264,81,19,4,40,2,28,15,11,85,214,4,103,63,37,3,30,325,11,191,2,247,205,272,13,10,4,107,14,30,12,21,16,65,206,6,1,13,48,4,3,177,64,236,9,3,302,2,53,68,7,17,233,303,6,3,25,5,2,22,78,22,269,38,11,2,249,153,137,12,8,10,3,196,96,24,116,10,19,246,15,71,9,43,7,27,17,7,3,2,110,49,6,6,6,6,6,39,168,9,56,148,3,272,83,7,64,59,22,2,5,24,159,38,3,10,294,19,7,140,246,3,4,41,6,6,9,5,13,5,2,7,241,186,11,2,27,11,9,3,95,53,11,154,3,23,8,108,214,47,94,213,51,3,17,34,117,3,12,13,5,246,85,21,5,4,8,14,15,26, ...

# %%
np.log(df_players.total_matches_played).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="f3307070-7bd6-4773-9ed4-38eb3e4be1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3307070-7bd6-4773-9ed4-38eb3e4be1da")) {                    Plotly.newPlot(                        "f3307070-7bd6-4773-9ed4-38eb3e4be1da",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_matches_played<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_matches_played","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_matches_played","offsetgroup":"total_matches_played","orientation":"v","showlegend":true,"type":"histogram","x":[2.1972245773362196,1.0986122886681098,1.791759469228055,2.3978952727983707,1.0986122886681098,1.791759469228055,5.056245805348308,2.772588722239781,1.0986122886681098,2.4849066497880004,1.6094379124341003,1.791759469228055,4.836281906951478,2.6390573296152584,1.3862943611198906,3.1354942159291497,1.3862943611198906,5.303304908059076,2.0794415416798357,2.3978952727983707,0.6931471805599453,2.0794415416798357,2.4849066497880004,3.367295829986474,3.258096538021482,3.9318256327243257,3.5263605246161616,1.791759469228055,3.58351893845611,3.044522437723423,4.770684624465665,2.8903717578961645,2.8903717578961645,1.0986122886681098,3.4011973816621555,1.6094379124341003,2.9444389791664403,5.786897381366708,5.666426688112432,0.6931471805599453,4.23410650459726,1.0986122886681098,1.0986122886681098,4.23410650459726,3.1354942159291497,1.6094379124341003,3.784189633918261,2.1972245773362196,3.912023005428146,2.0794415416798357,3.1354942159291497,4.499809670330265,2.0794415416798357,2.833213344056216,3.258096538021482,2.1972245773362196,1.791759469228055,3.6888794541139363,2.1972245773362196,2.4849066497880004,5.123963979403259,2.302585092994046,4.969813299576001,2.3978952727983707,1.3862943611198906,5.0689042022202315,4.499809670330265,1.3862943611198906,2.302585092994046,2.302585092994046,1.6094379124341003,2.4849066497880004,2.5649493574615367,2.3978952727983707,2.833213344056216,4.74493212836325,3.044522437723423,4.770684624465665,1.0986122886681098,2.995732273553991,2.0794415416798357,1.3862943611198906,1.0986122886681098,0.0,1.3862943611198906,1.9459101490553132,1.6094379124341003,5.442417710521793,2.3978952727983707,3.58351893845611,1.3862943611198906,4.859812404361672,2.8903717578961645,3.4011973816621555,3.295836866004329,5.303304908059076,4.718498871295094,5.44673737166631,1.6094379124341003,3.367295829986474,0.6931471805599453,4.454347296253507,3.258096538021482,0.6931471805599453,3.044522437723423,2.3978952727983707,5.442417710521793,0.6931471805599453,2.3978952727983707,4.356708826689592,4.343805421853684,1.791759469228055,3.970291913552122,5.786897381366708,3.8918202981106265,2.0794415416798357,2.1972245773362196,2.3978952727983707,4.543294782270004,1.0986122886681098,5.0369526024136295,5.204006687076795,2.772588722239781,1.0986122886681098,2.4849066497880004,1.0986122886681098,5.337538079701318,4.276666119016055,4.1588830833596715,5.318119993844216,2.9444389791664403,1.791759469228055,4.9344739331306915,3.6635616461296463,5.209486152841421,5.393627546352362,3.091042453358316,2.0794415416798357,1.3862943611198906,3.091042453358316,1.0986122886681098,5.5134287461649825,3.044522437723423,3.332204510175204,1.791759469228055,4.2626798770413155,4.941642422609304,2.302585092994046,3.6375861597263857,2.0794415416798357,4.248495242049359,3.044522437723423,3.4657359027997265,5.2832037287379885,3.9318256327243257,2.0794415416798357,1.0986122886681098,4.04305126783455,2.4849066497880004,0.6931471805599453,3.1354942159291497,2.833213344056216,3.1780538303479458,1.3862943611198906,1.791759469228055,3.6109179126442243,5.0106352940962555,0.6931471805599453, ...

# %% [markdown]
# ### Matches won

# %%
df_players.total_matches_won.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="a1123394-04c7-41be-801c-1c59bf630c48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1123394-04c7-41be-801c-1c59bf630c48")) {                    Plotly.newPlot(                        "a1123394-04c7-41be-801c-1c59bf630c48",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_matches_won<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_matches_won","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_matches_won","offsetgroup":"total_matches_won","orientation":"v","showlegend":true,"type":"histogram","x":[2,1,3,2,1,1,75,8,1,7,1,3,74,3,1,6,1,109,3,3,1,3,6,13,13,15,11,3,11,7,59,3,3,2,12,1,5,170,146,1,31,1,3,39,18,1,20,1,23,3,7,41,1,8,8,2,1,13,7,3,93,3,93,3,1,79,40,1,3,2,1,2,4,2,6,52,4,50,1,3,4,2,1,1,1,3,1,124,3,12,1,57,8,10,4,102,45,115,2,20,1,31,7,1,6,1,119,1,3,38,37,3,26,168,22,3,3,5,37,1,93,76,3,1,3,1,128,31,29,93,1,3,75,16,96,112,4,1,1,9,1,136,10,4,2,31,77,1,19,4,34,9,11,103,19,1,1,25,1,1,2,8,11,1,1,15,56,1,166,1,1,7,10,1,3,3,3,1,7,6,2,4,2,130,164,19,3,3,91,32,38,30,34,20,34,12,5,9,17,7,7,186,12,2,5,1,15,36,3,1,1,1,45,92,8,12,33,2,29,267,53,7,1,5,4,1,52,134,3,31,2,80,18,1,2,14,20,5,5,5,17,12,46,42,113,1,5,3,19,5,4,3,8,8,25,20,12,23,11,2,1,1,97,5,20,4,125,1,127,6,1,1,11,2,2,30,4,7,8,17,150,2,2,28,11,23,40,12,42,51,1,138,77,7,58,1,8,2,65,22,5,2,30,1,1,1,3,13,46,5,5,24,9,2,7,75,1,1,4,13,98,3,16,1,15,9,4,2,12,7,52,2,135,142,145,74,1,152,1,1,38,2,97,2,14,62,4,57,1,12,3,76,4,63,1,26,4,14,3,2,97,3,131,3,28,37,139,21,5,12,27,15,22,2,9,1,1,3,1,4,15,9,2,148,1,5,8,2,24,20,1,6,1,53,3,2,2,3,3,1,74,52,68,19,147,2,1,19,3,10,15,1,109,58,1,5,4,6,1,1,1,1,1,1,1,1,4,14,7,152,72,43,1,1,7,11,1,1,1,2,5,1,4,10,16,120,1,143,58,135,145,9,13,1,15,129,5,7,8,146,5,33,43,104,138,9,7,20,5,1,55,33,80,1,2,89,11,1,5,101,123,65,2,1,1,2,173,1,10,28,1,4,12,128,30,2,7,3,3,41,5,4,3,121,5,3,59,1,2,2,2,2,4,5,1,6,21,35,3,2,1,5,4,2,11,5,5,36,4,27,11,16,139,32,1,123,4,166,3,20,64,11,120,1,4,87,122,7,1,48,2,67,19,27,6,140,1,5,170,2,54,97,22,1,18,2,12,3,177,13,2,28,2,5,1,62,1,1,1,50,28,77,242,19,5,10,139,30,7,39,69,178,30,21,38,2,1,87,2,9,1,1,30,1,156,81,19,2,53,9,8,2,14,79,197,22,2,7,160,19,67,61,34,96,31,16,2,2,2,30,1,38,1,5,10,4,58,8,165,111,10,8,180,1,167,5,6,1,16,10,3,63,6,60,67,4,8,1,166,138,1,40,1,102,9,2,85,1,1,1,30,4,2,12,9,149,1,1,26,1,9,4,17,11,66,1,3,5,110,11,2,1,2,27,85,2,91,17,72,2,1,133,6,3,1,2,1,5,56,25,2,4,1,8,20,1,36,6,5,11,4,7,5,69,1,13,9,56,119,1,1,4,11,1,105,41,14,38,7,3,10,1,1,47,2,4,6,6,27,20,249,3,3,5,1,1,20,3,5,13,1,1,4,1,1,20,97,1,2,17,91,1,4,160,22,5,9,21,79,10,1,25,21,1,1,6,11,118,2,1,84,1,1,2,225,1,211,3,1,76,34,1,5,25,26,128,1,136,7,2,117,18,42,1,2,9,1,1,81,40,114,8,1,1,2,1,22,69,1,1,55,1,4,10,2,2,22,3,45,1,21,22,1,69,8,1,133,1,133,5,32,1,6,4,102,15,9,2,1,4,2,19,4,28,5,10,1,1,54,16,181,186,32,1,3,5,5,163,56,69,3,17,8,79,1,133,1,5,125,20,4,2,34,2,1,1,25,10,9,10,30,186,1,1,1,1,1,3,3,165,43,2,1,16,1,5,3,5,43,115,1,56,24,17,1,9,158,4,113,1,132,101,154,1,7,2,48,10,6,8,6,1,28,146,3,1,8,28,1,1,109,34,129,3,1,175,1,21,34,2,1,140,165,4,2,11,2,1,7,38,10,132,16,2,1,138,89,82,4,4,2,1,104,40,7,72,4,6,121,11,41,4,18,3,16,9,2,1,1,58,7,3,1,4,2,1,16,75,3,24,94,2,137,51,3,31,28,7,1,2,11,80,11,1,1,176,10,1,84,142,2,2,19,1,3,4,1,4,1,1,3,135,106,6,1,5,6,5,1,54,14,3,75,1,9,1,60,122,20,66,119,19,2,6,21,54,1,3,6,3,148,51,6,2,1,3,8,6,4,1,2,4,31,1,2,3,91,9,110,2,4,4,5,1,4,1,2,187,1,1,131,2,1,189,13,113,97,1,10,160,28,4,189,1,1,109,2,101,48,63,9,1,1,71,1,2,3,1,1,112,12,13,67,7,3,1,113,45,2,1,5,1,2,2,7,140,44,79,6,1,1,35,139,1,31,6,1,2,15,67,1,10,1,1,48,3,44,1,1,6,2,27,1,35,2,11,1,157,2,1,11,44,4,2,1,5,4,12,11,58,3,2,1,2,3,4,109,11,113,5,12,10,5,54,74,24,1,5,4,12,134,36,65,1,33,2,1,2,146,21,15,2, ...

# %%
np.log10(df_players.total_matches_won).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="d1fce378-199d-47da-ae11-6df742767798" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1fce378-199d-47da-ae11-6df742767798")) {                    Plotly.newPlot(                        "d1fce378-199d-47da-ae11-6df742767798",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=total_matches_won<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"total_matches_won","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"total_matches_won","offsetgroup":"total_matches_won","orientation":"v","showlegend":true,"type":"histogram","x":[0.3010299956639812,0.0,0.47712125471966244,0.3010299956639812,0.0,0.0,1.8750612633917,0.9030899869919435,0.0,0.8450980400142568,0.0,0.47712125471966244,1.8692317197309762,0.47712125471966244,0.0,0.7781512503836436,0.0,2.037426497940624,0.47712125471966244,0.47712125471966244,0.0,0.47712125471966244,0.7781512503836436,1.1139433523068367,1.1139433523068367,1.1760912590556813,1.041392685158225,0.47712125471966244,1.041392685158225,0.8450980400142568,1.7708520116421442,0.47712125471966244,0.47712125471966244,0.3010299956639812,1.0791812460476249,0.0,0.6989700043360189,2.230448921378274,2.164352855784437,0.0,1.4913616938342726,0.0,0.47712125471966244,1.591064607026499,1.255272505103306,0.0,1.3010299956639813,0.0,1.3617278360175928,0.47712125471966244,0.8450980400142568,1.6127838567197355,0.0,0.9030899869919435,0.9030899869919435,0.3010299956639812,0.0,1.1139433523068367,0.8450980400142568,0.47712125471966244,1.968482948553935,0.47712125471966244,1.968482948553935,0.47712125471966244,0.0,1.8976270912904414,1.6020599913279625,0.0,0.47712125471966244,0.3010299956639812,0.0,0.3010299956639812,0.6020599913279624,0.3010299956639812,0.7781512503836436,1.7160033436347992,0.6020599913279624,1.6989700043360187,0.0,0.47712125471966244,0.6020599913279624,0.3010299956639812,0.0,0.0,0.0,0.47712125471966244,0.0,2.093421685162235,0.47712125471966244,1.0791812460476249,0.0,1.7558748556724915,0.9030899869919435,1.0,0.6020599913279624,2.0086001717619175,1.6532125137753437,2.060697840353612,0.3010299956639812,1.3010299956639813,0.0,1.4913616938342726,0.8450980400142568,0.0,0.7781512503836436,0.0,2.075546961392531,0.0,0.47712125471966244,1.5797835966168101,1.568201724066995,0.47712125471966244,1.414973347970818,2.225309281725863,1.3424226808222062,0.47712125471966244,0.47712125471966244,0.6989700043360189,1.568201724066995,0.0,1.968482948553935,1.8808135922807914,0.47712125471966244,0.0,0.47712125471966244,0.0,2.1072099696478683,1.4913616938342726,1.462397997898956,1.968482948553935,0.0,0.47712125471966244,1.8750612633917,1.2041199826559248,1.9822712330395684,2.0492180226701815,0.6020599913279624,0.0,0.0,0.9542425094393249,0.0,2.1335389083702174,1.0,0.6020599913279624,0.3010299956639812,1.4913616938342726,1.8864907251724818,0.0,1.2787536009528289,0.6020599913279624,1.5314789170422551,0.9542425094393249,1.041392685158225,2.012837224705172,1.2787536009528289,0.0,0.0,1.3979400086720377,0.0,0.0,0.3010299956639812,0.9030899869919435,1.041392685158225,0.0,0.0,1.1760912590556813,1.7481880270062005,0.0,2.220108088040055,0.0,0.0,0.8450980400142568,1.0,0.0,0.47712125471966244,0.47712125471966244,0.47712125471966244,0.0,0.8450980400142568,0.7781512503836436,0.3010299956639812,0.6020599913279624,0.3010299956639812,2.113943352306837,2.214843848047698,1.2787536009528289,0.47712125471966244,0.47712125471966244,1.9590413923210936,1.505149978319906,1.5797835966168101,1.4771212547196624,1.5314789170422551,1.3010299956639813,1.5314789170422551,1.0791812460476249,0.6989700043360189,0.9542425094393249,1.2304489213782739,0.8450980400142568,0.8450980400142568,2.2695129442179165,1.0791812460476249,0.301 ...

# %% [markdown]
# ### Age

# %%
df_players.age.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="d207599e-a783-4736-a534-c7211cce9f1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d207599e-a783-4736-a534-c7211cce9f1b")) {                    Plotly.newPlot(                        "d207599e-a783-4736-a534-c7211cce9f1b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=age<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"age","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"age","offsetgroup":"age","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,20.1642710472,17.5715263518,18.8720054757,21.5414099932,17.9411362081,null,15.3511293634,15.5482546201,17.0458590007,23.7453798768,20.5612594114,27.1759069131,26.5763175907,23.9315537303,21.2402464066,null,null,null,23.6632443532,null,26.1081451061,null,16.9582477755,18.3983572895,null,23.9370294319,17.7029431896,15.5208761123,null,17.8590006845,null,15.356605065,20.4873374401,21.0047912389,27.5154004107,30.1848049281,20.7885010267,31.0171115674,24.2600958248,24.2217659138,22.6940451745,21.6481861739,16.5311430527,18.3655030801,17.1225188227,29.1718001369,24.9336071184,15.7180013689,15.0882956879,22.6255989049,20.6516084873,15.3374401095,26.1957563313,19.4825462012,25.5441478439,null,null,22.2012320329,18.2614647502,26.8309377139,16.9856262834,48.9363449692,23.613963039,19.318275154,17.6125941136,20.1067761807,17.6646132786,24.8815879535,19.4250513347,null,20.1533196441,17.8069815195,22.507871321,23.1266255989,22.8829568789,null,16.1916495551,36.8158795346,16.6351813826,15.2854209446,null,24.2108145106,null,19.9698836413,22.6611909651,14.7433264887,27.4551676934,18.1026694045,31.8384668036,24.4900752909,20.7830253251,22.6529774127,22.9295003422,23.8275154004,18.945927447,18.6283367556,19.6331279945,23.8767967146,21.6098562628,17.1635865845,null,null,17.9575633128,19.9452429843,18.3655030801,null,16.372347707,24.2272416153,21.234770705,35.1430527036,27.9644079398,35.8056125941,32.1396303901,16.6707734428,20.2902121834,23.6878850103,null,22.2176591376,28.038329911,25.1252566735,18.7241615332,22.2559890486,17.3661875428,17.8863791923,32.1396303901,24.4298425736,26.9048596851,26.0917180014,17.8343600274,19.0691307324,18.212183436,19.7453798768,28.8843258042,18.3381245722,17.7796030116,16.3969883641,null,20.8432580424,22.8062970568,17.029431896,16.5886379192,null,14.9952087611,17.7412731006,19.2580424367,18.674880219,null,28.3449691992,null,22.4010951403,23.9425051335,16.205338809,18.674880219,17.0869267625,21.0951403149,18.4722792608,null,18.0698151951,19.4004106776,17.1718001369,17.916495551,null,15.1594798084,25.0951403149,32.6132785763,25.5989048597,27.5071868583,37.0787132101,25.6262833676,17.1854893908,null,18.3299110198,17.9000684463,null,null,24.2737850787,14.945927447,16.8761122519,17.0458590007,24.2902121834,22.9952087611,16.8980150582,28.9117043121,22.4804928131,22.0342231348,18.4750171116,19.0116358658,26.3545516769,17.5523613963,25.9356605065,14.7460643395,19.5646817248,24.9856262834,14.6858316222,18.2368240931,25.5660506502,22.1327857632,17.749486653,18.7214236824,28.9582477755,21.4729637235,17.9575633128,19.5154004107,18.4941820671,30.1902806297,25.568788501,22.2203969884,24.4161533196,17.8754277892,22.3189596167,25.7549623546,20.5722108145,20.8733744011,26.006844627,20.3258042437,24.3942505133,18.7460643395,27.1759069131,24.1177275838,16.9062286105,14.984257358,null,17.7796030116,17.0376454483,25.6919917864,27.1403148528,26.8993839836,16.6516084873,26.598220397,14.7761806982,null,15.5482546201,20.2409308693,15.0171115674,16.7474332649,null,17.2648870637,20.8980150582,28.2902121834,23.4633812457,26.841889117,24.4928131417,14.2970568104,16.090349076,null,24.7474332649,17.0732375086,15. ...

# %%
np.log(df_players.age).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="656ec7c3-ac52-49bb-998f-7a496cbdc852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("656ec7c3-ac52-49bb-998f-7a496cbdc852")) {                    Plotly.newPlot(                        "656ec7c3-ac52-49bb-998f-7a496cbdc852",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=age<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"age","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"age","offsetgroup":"age","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,3.003912278264537,2.8662797710382066,2.9376796322547594,3.0699771288802125,2.887096188409989,null,2.731189045489627,2.7439483892451313,2.835907300371656,3.1673879800537854,3.0234086941292158,3.302330805517562,3.2800205030817446,3.1751978279487725,3.0558977973704766,null,null,null,3.163922973122558,null,3.2622473386746393,null,2.830754309902561,2.91226138288488,null,3.175426608550251,2.873730907654786,2.742185963696595,null,2.8825076211673757,null,2.731545678875968,3.019807009449085,3.0447505659335374,3.3147458628572264,3.407338649683197,3.0343999985827113,3.4345390382420486,3.188832853417419,3.1872516468543233,3.1221025629590433,3.074921671442265,2.805246059635756,2.9104740723132636,2.8403944873855664,3.3732024939021645,3.2162165769365267,2.754806639535212,2.71391932325342,3.1190819601704476,3.027793209221009,2.73029690518833,3.2655974255603697,2.969518998153273,3.2404082432089165,null,null,3.1001477843158107,2.9047930882804422,3.289555614028056,2.8323674736675306,3.8905203713105454,3.161838191268143,2.9610515470556056,2.86861422077901,3.0010568816696095,2.8715633886156313,3.2141280903318705,2.966563538963218,null,3.0033690214289193,2.879590600596434,3.113865084520747,3.1409845770964777,3.1303923923792323,null,2.78449564978166,3.6059292611940017,2.811519813083974,2.7268994946822653,null,3.1867994139445472,null,2.9942253207357363,3.1206538122549223,2.690790538959248,3.3125544086488063,2.8960594083091418,3.460675206663516,3.1982679453121476,3.0341365633850077,3.1202912963891793,3.132424306061091,3.170841022158257,2.941588997983327,2.92468390288243,2.9772183432505286,3.172907138597054,3.0731495190760354,2.842790080641345,null,null,2.8880113806629573,2.992990668000634,2.9104740723132636,null,2.7955937963108166,3.187477686635222,3.0556399657318947,3.5594269515981516,3.33093255657795,3.578104657490032,3.4700898602463526,2.8136570929749243,3.0101386113187756,3.164963736443536,null,3.100887429318918,3.333572499443921,3.2238735821877547,2.9298147504674774,3.102611143115905,2.854525071004302,2.8840394842080395,3.4700898602463526,3.195805441270172,3.2923069277298653,3.26161794601863,2.881126935206575,2.948070835584404,2.9020907896818593,2.9829195336925656,3.3632990882718916,2.9089822027227514,2.878051902029965,2.7970976816315707,null,3.0370305406736433,3.127036684529623,2.834943135104667,2.808717998312167,null,2.707730734151411,2.8758937387146086,2.9579287624037836,2.9271793170224076,null,3.3444495611360576,null,3.109109847857872,3.1756553368231373,2.785340744057762,2.9271793170224076,2.8383136543037346,3.049042697125643,2.916271189997684,null,2.8942428773852646,2.965294234793677,2.8432685113998692,2.8857218276521945,null,2.7186260661954273,3.22267421444014,3.4847195237324966,3.242549571652504,3.3144473108309156,3.613043037023752,3.2436185188425277,2.844065387685082,null,2.908534207491768,2.884804536655041,null,null,3.1893969646736458,2.704438851154017,2.825899145810248,2.835907300371656,3.190073478397912,3.1352858794938387,2.8271961628534656,3.364246506628925,3.1126479470761255,3.0925968417069347,2.9164193930368136,2.945051205706994,3.2716409992309705,2.8651884933562264,3.2556188752446333,2.6909762227411 ...

# %% [markdown]
# ### Hand

# %% [markdown]
# ### Ranking

# %%
df_players.variance_rank_points.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="37bb89fc-2c1c-456e-ac87-041dc4effbd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37bb89fc-2c1c-456e-ac87-041dc4effbd0")) {                    Plotly.newPlot(                        "37bb89fc-2c1c-456e-ac87-041dc4effbd0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=variance_rank_points<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"variance_rank_points","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"variance_rank_points","offsetgroup":"variance_rank_points","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,2.41,null,null,4132.180615846484,33.43359375,null,null,null,null,1623.9007306626356,null,null,1216.944214876033,0.0,24954.298408455234,null,null,null,null,null,637.1160714285714,null,1.448888888888889,null,null,0.24489795918367346,null,118.08984013740258,null,null,null,2039.9540816326528,11.440000000000001,880.0498614958448,99931.59004855281,10123.812789597825,0.0,7204.621298046629,null,null,5.822714681440442,0.0,null,11.416666666666668,null,834.6564,71.109375,0.0,132.63548483045807,null,8.010000000000002,0.0,null,0.0,0.234375,null,null,1955.8690121882087,null,2588682.663580247,null,null,7129.483169178436,13.18383742911153,null,null,0.25,null,null,null,null,1056.9375,105.5799766181316,0.0,81.32900028727376,null,null,null,null,null,0.0,0.0,null,28.6875,132292.295608398,null,343.21,null,724.9999399074575,11.88888888888889,0.7397959183673469,0.21301775147928997,5015.252147224079,20.98996913580247,4791.051426872772,null,0.0,0.0,206.1719214753123,null,null,null,1.4285714285714286,594.2596420054274,null,null,17.159209157127993,2210.070500927644,0.0,9087.708081167675,178893.09801836725,433.11286963765093,162.6875,0.0,15.157024793388427,196.3163265306123,null,2576.217070025789,5877.858350440768,null,null,null,null,207996.5260493713,15932.888888888889,1130.6552734375,16351.853806228379,80.20061728395063,12.25,22291.915224913493,1045.0824489795918,11912.960733375137,2139.6367561983475,0.20408163265306123,null,null,null,null,80974.60275754423,2.076388888888889,null,null,45.177501826150475,172.08880796670633,null,24.243767313019383,null,2425.849795918367,null,4897.54577883472,3356.5346182586513,646.9527104959633,null,null,1086.6537396121885,0.0,null,null,2.1487603305785123,null,null,null,3.7451523545706373,1883.8819555555556,null,6710.9935170348035,2.0,null,1333.8274999999999,null,null,0.0,0.0,null,null,0.5714285714285714,null,null,null,12.25,14635.638641520945,539096.214627487,365.20570749108197,null,11.555555555555555,14178.644495317376,701.3514792899407,7829.585423875433,238.44428622285508,832.9934321636329,21.90027700831025,5.478280240588104,5.4875,35.01,340.00692041522495,640.859375,0.24221453287197234,97.92888888888888,184572.31029707022,1.9591836734693882,115.96,130.6875,342.0,1459.4126297577855,4543.690230802729,119.91836734693878,0.0,2.2399999999999998,0.25,3491.8672839506175,6490.1982335096245,339.4214876033058,169.84504132231405,3234.635984923626,36.0,703.3562885802471,3567711.0239914893,67637.96196451328,165.99826388888889,null,0.22222222222222224,null,null,893.7610416666668,3043.914840083224,null,76.7375283446712,0.6399999999999999,46970.27286980968,610.4375,null,null,40.10204081632653,0.0,0.1875,null,0.0,102.91650230111766,51.49716446124764,358.67516727685893,18436.91124857972,401.79724685717696,null,0.24,null,25.854166666666668,129.5822222222222,0.0,null,63.08159722222223,14.576388888888888,0.8099999999999999,172.76859012492565,10.0,7.800400980173758,14.532544378698223,null,0.0,0.0,8948.631616457882,5.520833333333333,2855.6666666666665,231.06172839506175,85680.57336126557,null,4464.210701530612,544.0555555555555,null,0.0,103 ...

# %%
np.log1p(df_players.variance_rank_points).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="9c99711b-04c5-4c6b-9f5b-fc915605d76c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c99711b-04c5-4c6b-9f5b-fc915605d76c")) {                    Plotly.newPlot(                        "9c99711b-04c5-4c6b-9f5b-fc915605d76c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=variance_rank_points<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"variance_rank_points","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"variance_rank_points","offsetgroup":"variance_rank_points","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,1.2267122912954256,null,null,8.326802514463356,3.539032650352408,null,null,null,null,7.393202004074846,null,null,7.104919646626573,0.0,10.124841439694576,null,null,null,null,null,6.458520196936336,null,0.8956344069484944,null,null,0.21905356606268464,null,4.779878167411068,null,null,null,7.62117266458158,2.5209170873110334,6.781114220811214,11.512251138148521,9.222744401887535,0.0,8.88261673622827,null,null,1.9202574397876568,0.0,null,2.519039656157459,null,6.728217523814396,4.278184063577281,0.0,4.895115830854175,null,2.1983350716202468,0.0,null,0.0,0.21056476910734964,null,null,7.57910103219133,null,14.766660066479107,null,null,8.872134276775528,2.6521031071376613,null,null,0.22314355131420976,null,null,null,null,6.964076536949316,4.668895657485347,0.0,4.410723418485168,null,null,null,null,null,0.0,0.0,null,3.39072608179486,11.792776673145507,null,5.841251936231647,null,6.587549932052696,2.5563656137701454,0.5537678180529996,0.19311126421533473,8.520438349634677,3.0905864010096353,8.47471387155589,null,0.0,0.0,5.333548987087172,null,null,null,0.8873031950009028,6.388997683480935,null,null,2.8991778236085786,7.701232066793066,0.0,9.114788051786686,12.094549278557798,6.073304568578028,5.09795912226793,0.0,2.782354926822725,5.28480815938002,null,7.8544654407198875,8.679117863953246,null,null,null,null,12.245281464619314,9.676203496707068,7.0314366836193685,9.70215770581769,4.396922849157834,2.583997552432231,10.012024204051269,6.952807464634734,9.385466162344285,7.6688586133821826,0.18571714579509285,null,null,null,null,11.301903187760441,1.123756470469135,null,null,3.8324927060176632,5.153804803631454,null,3.2285792861632454,null,7.794349315026231,null,8.49669366022122,8.118962239069077,6.4738177160595916,null,null,6.991778122729411,0.0,null,null,1.1470088295299599,null,null,null,1.557123539991239,7.541620474873755,null,8.811651282269759,1.0986122886681096,null,7.196557349002423,null,null,0.0,0.0,null,null,0.4519851237430572,null,null,null,2.583997552432231,9.591283160163954,13.197651194717986,5.9031952178400955,null,2.5301632413761213,9.559562728919751,6.554433961475229,8.965792552968423,5.478320764415191,6.72622552722418,3.1311490069197947,1.8684550801697342,1.869877248492007,3.583796677660784,5.8319027715503875,6.464369237640671,0.21689570037584674,4.59440129798619,12.125802009325367,1.084913444309948,4.761831996001468,4.880431691564408,5.83773044716594,7.286474297893762,8.421714848249847,4.795115667892706,0.0,1.175573329804238,0.22314355131420976,8.158478249224036,8.778202420315965,5.830184519276001,5.140756954565711,8.081980782643218,3.6109179126442243,6.557284319870119,15.08743505866003,11.121939456420975,5.1179834164878,null,0.20067069546215116,null,null,6.796556690074788,8.021228212620963,null,4.35333813105025,0.494696241836107,10.757291478287867,6.415812742217647,null,null,3.716057775167881,0.0,0.17185025692665923,null,0.0,4.643587714185422,3.9607591578770216,5.885201311000792,9.822164217841136,5.998433325809074,null,0.2151113796169455,null,3.2904209920312963,4.872003083703911,0.0,null,4.160157227889892,2.7457562349442 ...

# %%
df_players.last_rank_points.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="b3a4e161-ae1b-4cbf-ac5f-0d9289384880" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3a4e161-ae1b-4cbf-ac5f-0d9289384880")) {                    Plotly.newPlot(                        "b3a4e161-ae1b-4cbf-ac5f-0d9289384880",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=last_rank_points<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"last_rank_points","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"last_rank_points","offsetgroup":"last_rank_points","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,8.0,null,null,175.0,7.0,null,null,null,null,96.0,null,null,31.0,69.0,88.0,null,null,null,null,null,7.0,null,6.0,null,null,3.0,null,36.0,null,null,null,150.0,7.0,7.0,1571.0,199.0,1.0,36.0,null,null,10.0,20.0,null,11.0,null,54.0,124.0,3.0,38.0,null,56.0,3.0,null,9.0,8.0,null,null,26.0,null,1002.0,null,null,142.0,20.0,null,null,3.0,null,null,null,null,112.0,15.0,3.0,31.0,null,null,null,null,null,1.0,1.0,null,13.0,1490.0,null,4.0,null,108.0,28.0,3.0,4.0,194.0,14.0,191.0,null,8.0,3.0,41.0,null,null,null,7.0,65.0,null,null,21.0,40.0,81.0,155.0,1400.0,33.0,33.0,3.0,29.0,4.0,null,155.0,89.0,null,null,null,null,1723.0,120.0,60.0,86.0,18.0,8.0,462.0,100.0,319.0,133.0,4.0,null,null,null,null,414.0,12.0,null,null,21.0,12.0,null,16.0,null,139.0,null,49.0,265.0,70.0,null,null,20.0,3.0,null,null,8.0,null,null,null,8.0,116.0,null,432.0,14.0,null,93.0,null,null,4.0,3.0,null,null,6.0,null,null,null,15.0,519.0,2600.0,171.0,null,31.0,504.0,100.0,213.0,3.0,3.0,24.0,4.0,10.0,3.0,67.0,16.0,2.0,31.0,1633.0,3.0,35.0,31.0,46.0,158.0,114.0,34.0,1.0,1.0,4.0,183.0,80.0,128.0,25.0,148.0,21.0,52.0,7263.0,966.0,33.0,null,4.0,null,null,75.0,270.0,null,13.0,6.0,147.0,85.0,null,null,4.0,8.0,4.0,null,3.0,15.0,31.0,46.0,73.0,37.0,null,4.0,null,9.0,19.0,3.0,null,18.0,15.0,6.0,44.0,3.0,8.0,19.0,null,1.0,1.0,353.0,1.0,192.0,6.0,970.0,null,154.0,103.0,null,3.0,20.0,null,5.0,99.0,76.0,null,15.0,9.0,860.0,null,32.0,4.0,4.0,43.0,9.0,9.0,28.0,46.0,null,157.0,51.0,27.0,74.0,null,3.0,null,56.0,4.0,null,null,32.0,null,3.0,null,null,6.0,124.0,null,null,null,null,null,16.0,19.0,null,null,4.0,6.0,524.0,null,4.0,null,116.0,null,null,null,6.0,null,64.0,null,1771.0,1230.0,1130.0,53.0,null,1147.0,null,1.0,112.0,null,273.0,null,4.0,36.0,4.0,9.0,8.0,3.0,null,425.0,109.0,287.0,null,81.0,null,10.0,null,null,1015.0,null,128.0,null,33.0,6.0,327.0,5.0,7.0,null,47.0,7.0,3.0,null,null,null,null,null,null,null,12.0,9.0,null,230.0,null,15.0,null,27.0,227.0,3.0,null,5.0,null,83.0,null,3.0,null,null,null,null,54.0,70.0,12.0,15.0,826.0,null,null,10.0,null,4.0,1560.0,null,920.0,54.0,null,null,null,null,null,null,null,null,null,null,null,null,4.0,20.0,7.0,261.0,12.0,55.0,null,null,null,null,8.0,null,null,null,null,null,8.0,null,5.0,90.0,null,67.0,34.0,437.0,38.0,null,9.0,null,null,156.0,null,null,null,3390.0,null,13.0,36.0,895.0,67.0,4.0,5.0,14.0,3.0,null,49.0,26.0,213.0,null,null,17.0,null,null,3.0,308.0,98.0,58.0,3.0,null,null,null,1169.0,null,null,11.0,null,null,null,300.0,49.0,null,null,null,null,19.0,null,8.0,7.0,98.0,null,null,85.0,null,null,null,null,null,6.0,null,null,5.0,9.0,17.0,null,null,null,null,null,null,null,3.0,null,48.0,9.0,11.0,8.0,8.0,183.0,61.0,null,366.0,null,123.0,19.0,43.0,14.0,24.0,306.0,null,null,278.0,1147.0,13.0,null,45.0,null,110.0,121.0,41.0,5.0,873.0,null,null,113.0,null,48.0,148.0,7.0,7.0,12.0,null,null,3.0,667.0,40.0,4.0,10.0,null,1.0,10.0,251.0,null,31.0,1.0,39.0,23.0,210.0,6005.0,49.0,null,5.0,730.0,42.0,null,10.0,66.0,2090.0,7.0,5.0,40.0,null,null,76.0,null,null,null,null,16.0,null,107.0,52.0,4.0,null,89.0,null,9.0,null,13.0,24.0,2950.0,12.0,null,3.0,1008.0,null,41.0,22.0,42.0,2 ...

# %%
np.sqrt(np.log(df_players.last_rank_points)).hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="350a2716-284d-49e2-8ee6-5cb5060c3ce2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("350a2716-284d-49e2-8ee6-5cb5060c3ce2")) {                    Plotly.newPlot(                        "350a2716-284d-49e2-8ee6-5cb5060c3ce2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=last_rank_points<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"last_rank_points","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"last_rank_points","offsetgroup":"last_rank_points","orientation":"v","showlegend":true,"type":"histogram","x":[null,null,null,1.442026886600883,null,null,2.272616547929614,1.3949588341794583,null,null,null,null,2.1364335214248618,null,null,1.853102049128743,2.057694463373331,2.1159718368820997,null,null,null,null,null,1.3949588341794583,null,1.3385661990458504,null,null,1.048147073968205,null,1.8930184728248454,null,null,null,2.2384448382965028,1.3949588341794583,1.3949588341794583,2.7128338759046087,2.3007183279846517,0.0,1.8930184728248454,null,null,1.5174271293851465,1.7308183826022854,null,1.5485138917033876,null,1.997244112912659,2.195513963882953,1.048147073968205,1.9072456998840988,null,2.0063279120660087,1.048147073968205,null,1.4823038073675112,1.442026886600883,null,null,1.8050198165176699,null,2.6286409571572933,null,null,2.2261686947761308,1.7308183826022854,null,null,1.048147073968205,null,null,null,null,2.1722105955213213,1.6456154475156735,1.048147073968205,1.853102049128743,null,null,null,null,null,0.0,0.0,null,1.6015459273656616,2.7030596365858273,null,1.1774100225154747,null,2.163823289255437,1.8254326912201402,1.048147073968205,1.1774100225154747,2.295181508958132,1.624517568269195,2.291783896454164,null,1.442026886600883,1.048147073968205,1.9270630676509546,null,null,null,1.3949588341794583,2.043131730920852,null,null,1.7448559934055943,1.9206455826398414,2.09629414793641,2.2457571366733418,2.691510266672477,1.8698950669667216,1.8698950669667216,1.048147073968205,1.835019299622343,1.1774100225154747,null,2.2457571366733418,2.1186402171515906,null,null,null,null,2.7298026002859492,2.188033761801231,2.023448680402372,2.110532467472014,1.70010933704164,1.442026886600883,2.477007244858549,2.145966026289347,2.4010812361902385,2.211413377960293,1.1774100225154747,null,null,null,null,2.4547639344395855,1.5763586678760644,null,null,1.7448559934055943,1.5763586678760644,null,1.6651092223153954,null,2.2213675817231806,null,1.9727697022487511,2.3621451746212005,2.061187823088755,null,null,1.7308183826022854,1.048147073968205,null,null,1.442026886600883,null,null,null,1.442026886600883,2.1802729625224373,null,2.463417461220106,1.624517568269195,null,2.1289902520099186,null,null,1.1774100225154747,1.048147073968205,null,null,1.3385661990458504,null,null,null,1.6456154475156735,2.500380747639425,2.804151694186599,2.2675236617293897,null,1.853102049128743,2.4945092238898154,2.145966026289347,2.3154464290303554,1.048147073968205,1.048147073968205,1.782709687623856,1.1774100225154747,1.5174271293851465,1.048147073968205,2.050534715480566,1.6651092223153954,0.8325546111576977,1.853102049128743,2.7199584726555046,1.048147073968205,1.8855630621884312,1.853102049128743,1.9566914413082854,2.2500211183513295,2.1762808753454816,1.8778606243851437,0.0,0.0,1.1774100225154747,2.282429879063412,2.093329079402921,2.2027324540033493,1.7941225779941015,2.23544453605186,1.7448559934055943,1.9877735581754346,2.981702239595055,2.621671953966117,1.8698950669667216,null,1.1774100225154747,null,null,2.0778566152495483,2.366098467730871,null,1.6015459273656616,1.3385661990458504,2.2339276144894975,2.1077597720068377,null,null,1.1774100225154747,1.442026886600883,1.1774100225154747,nul ...

# %% [markdown]
# ## Correlation analysis

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

correlation = df_players.corr(method="pearson") #.abs()
correlation = correlation.where(np.tril(np.ones(correlation.shape)).astype(bool))
px.imshow(correlation[(correlation>=0.8) | (correlation<=-0.8)], zmin=0, zmax=1, width=1000, height=1000).show()

correlation = correlation.unstack().drop(labels=get_redundant_pairs(correlation)).sort_values(ascending=False).drop_duplicates()
print(f"These are {len(correlation[(correlation>=0.8) | (correlation<=-0.8)])} pairs whose correlation is higer than 80%:")
correlation[(correlation>=0.8) | (correlation<=-0.8)]
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="8daf6ccc-02e5-4ebf-a98e-c353bb2b1593" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8daf6ccc-02e5-4ebf-a98e-c353bb2b1593")) {                    Plotly.newPlot(                        "8daf6ccc-02e5-4ebf-a98e-c353bb2b1593",                        [{"coloraxis":"coloraxis","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>","name":"0","type":"heatmap","x":["total_tourneys_played","total_matches_played","total_matches_won","mean_won_ratio","max_won_ratio","min_won_ratio","ht","age","mean_rank_points","max_rank_points","last_rank_points","variance_rank_points","mean_tourney_spectators","max_tourney_spectators","mean_tourney_revenue","max_tourney_revenue"],"xaxis":"x","y":["total_tourneys_played","total_matches_played","total_matches_won","mean_won_ratio","max_won_ratio","min_won_ratio","ht","age","mean_rank_points","max_rank_points","last_rank_points","variance_rank_points","mean_tourney_spectators","max_tourney_spectators","mean_tourney_revenue","max_tourney_revenue"],"yaxis":"y","z":[[1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[0.9849300817215114,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[0.9452718738102834,0.9871047112816804,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,1.0,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,1.0,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,1.0,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,1.0,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,0.962243231585632,1.0,null,null,null,null,null,null],[null,null,null,null,null,null,null,null,0.801597596918581,0.878968810129297,1.0,null,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,1.0,null,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,1.0,null,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,null,1.0,null,null],[null,null,null,null,null,null,null,null,null,null,null,null,0.9504111706941722,null,1.0,null],[null,null,null,null,null,null,null,null,null,null,null,null,null,0.9670921478435447,null,1.0]]}],                        {"coloraxis":{"cmax":1,"cmin":0,"colorscale":[[0.0,"rgb(2,4,25)"],[0.0625,"rgb(24,15,41)"],[0.125,"rgb(47,23,57)"],[0.1875,"rgb(71,28,72)"],[0.25,"rgb(97,30,82)"],[0.3125,"rgb(123,30,89)"],[0.375,"rgb(150,27,91)"],[0.4375,"rgb(177,22,88)"],[0.5,"rgb(203,26,79)"],[0.5625,"rgb(223,47,67)"],[0.625,"rgb(236,76,61)"],[0.6875,"rgb(242,107,73)"],[0.75,"rgb(244,135,95)"],[0.8125,"rgb(245,162,122)"],[0.875,"rgb(246,188,153)"],[0.9375,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]]},"height":1000,"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor": ...
# These are 8 pairs whose correlation is higer than 80%:
# total_matches_played     total_matches_won       0.987105
# total_tourneys_played    total_matches_played    0.984930
# max_tourney_spectators   max_tourney_revenue     0.967092
# mean_rank_points         max_rank_points         0.962243
# mean_tourney_spectators  mean_tourney_revenue    0.950411
# total_tourneys_played    total_matches_won       0.945272
# max_rank_points          last_rank_points        0.878969
# mean_rank_points         last_rank_points        0.801598
# dtype: float64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=56da3ab5-e195-41aa-a609-f5fefeb3379d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
